# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.width',2000)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
dataset = pd.read_csv('NFT_Sales.csv', delimiter=',')
dataset
# Out:
#             Date  Sales_USD_cumsum  Number_of_Sales_cumsum  Active_Market_Wallets_cumsum  Primary_Sales_cumsum  Secondary_Sales_cumsum  AverageUSD_cum   Sales_USD  Number_of_Sales  Active_Market_Wallets  Primary_Sales
# 0     2017-06-22              0.00                       0                          0.00                     0                     NaN             NaN         NaN              NaN                    NaN            NaN
# 1     2017-06-23           1020.30                      19                          8.00                     0                   19.00           53.70     1020.30            19.00                   8.00           0.00
# 2     2017-06-24           2261.14                      40                         21.00                     0                   21.00           56.53     1240.84            21.00                  13.00           0.00
# ...

# %%
dataset.drop('Sales_USD_cumsum', inplace=True, axis=1)
dataset.drop('Number_of_Sales_cumsum', inplace=True, axis=1)
dataset.drop('Active_Market_Wallets_cumsum', inplace=True, axis=1)
dataset.drop('Primary_Sales_cumsum', inplace=True, axis=1)
dataset.drop('Secondary_Sales_cumsum', inplace=True, axis=1)
dataset.drop('AverageUSD_cum', inplace=True, axis=1)

# %%
dataset
# Out:
#             Date   Sales_USD  Number_of_Sales  Active_Market_Wallets  Primary_Sales
# 0     2017-06-22         NaN              NaN                    NaN            NaN
# 1     2017-06-23     1020.30            19.00                   8.00           0.00
# 2     2017-06-24     1240.84            21.00                  13.00           0.00
# 3     2017-06-25      517.55            13.00                   7.00           0.00
# 4     2017-06-26      424.63            14.00                   6.00           0.00
# ...          ...         ...              ...                    ...            ...
# 1601  2021-11-08 77066977.22         59264.00                    NaN       44435.00
# 1602  2021-11-09 51975076.60         50879.00                    NaN       32156.00
# 1603  2021-11-10 59010338.62         44822.00                    NaN       27694.00
# 1604  2021-11-11 35543166.10         13935.00                    NaN        7808.00
# ...

# %%
dataset=dataset.drop(dataset.index[1605])
dataset=dataset.drop(dataset.index[0])

# %%
dataset
# Out:
#             Date   Sales_USD  Number_of_Sales  Active_Market_Wallets  Primary_Sales
# 1     2017-06-23     1020.30            19.00                   8.00           0.00
# 2     2017-06-24     1240.84            21.00                  13.00           0.00
# 3     2017-06-25      517.55            13.00                   7.00           0.00
# 4     2017-06-26      424.63            14.00                   6.00           0.00
# 5     2017-06-27     2092.91            33.00                  10.00           0.00
# ...          ...         ...              ...                    ...            ...
# 1600  2021-11-07 62408291.91         44347.00                    NaN       24606.00
# 1601  2021-11-08 77066977.22         59264.00                    NaN       44435.00
# 1602  2021-11-09 51975076.60         50879.00                    NaN       32156.00
# 1603  2021-11-10 59010338.62         44822.00                    NaN       27694.00
# ...

# %%
dataset.describe()
# Out:
#          Sales_USD  Number_of_Sales  Active_Market_Wallets  Primary_Sales
# count      1604.00          1604.00                1597.00        1604.00
# mean    6380649.38          6872.06                 502.88        4120.33
# std    24866794.69         12612.25                1363.81        7580.10
# min           0.00             0.00                -573.00           0.00
# 25%       46085.53          2279.25                  69.00        1462.75
# 50%       82227.25          3683.50                 126.00        2358.50
# 75%      352914.58          5844.50                 267.00        3698.00
# max   388636358.49        161732.00               30129.00       93609.00

# %%
dataset.isnull().sum()
# Out:
# Date                     0
# Sales_USD                0
# Number_of_Sales          0
# Active_Market_Wallets    7
# Primary_Sales            0
# dtype: int64

# %%
dataset['Active_Market_Wallets'].mode()
# Out:
# 0   0.00
# Name: Active_Market_Wallets, dtype: float64

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Date                     0
# Sales_USD                0
# Number_of_Sales          0
# Active_Market_Wallets    0
# Primary_Sales            0
# dtype: int64

# %%
#draw box plot for active wallets and detect outlier 
#remove outlier and replace nan with mean

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
print(dataset['Active_Market_Wallets'].describe())
plt.figure(figsize =(10, 7))
plt.ylim(-600, 1000)
plot=dataset.boxplot(['Active_Market_Wallets'])
# Out:
# count    1597.00
# mean      502.88
# std      1363.81
# min      -573.00
# 25%        69.00
# 50%       126.00
# 75%       267.00
# max     30129.00
# Name: Active_Market_Wallets, dtype: float64

# %%
q1,q2,q3=dataset.Active_Market_Wallets.quantile([0.25,0.5,0.75]).values

# %%
q9=dataset.Active_Market_Wallets.quantile(0.90)
print(q9)
# Out:
# 1131.6000000000045

# %%
IR = q3 -q1
print(IR)
# Out:
# 198.0

# %%
min = q1-1.5*IR
print(min)
# Out:
# -228.0

# %% [markdown]
# donc le vrai min de notre data est : -228.0

# %%
max = q3+1.5*IR
print(max)
# Out:
# 564.0

# %% [markdown]
# donc le vrai max est 564.0

# %%
idmin = dataset['Active_Market_Wallets'].idxmin()

# %%
# dataset['Active_Market_Wallets'][idmin] = np.nan

# %%
# dataset['Active_Market_Wallets'][idmin]

# %%
# dataset['Active_Market_Wallets'].describe()

# %%
# plt.figure(figsize =(10, 7))
# plt.ylim(0, 1000)
# plot=dataset.boxplot(['Active_Market_Wallets'])

# %%
dataset['Active_Market_Wallets'] = np.where(dataset['Active_Market_Wallets'] > q9, q2, dataset['Active_Market_Wallets'])

# %%
print(dataset['Active_Market_Wallets'].describe())
plt.figure(figsize =(10, 7))
plt.ylim(0, 1000)
plot=dataset.boxplot(['Active_Market_Wallets'])
# Out:
# count   1597.00
# mean     176.06
# std      207.58
# min     -573.00
# 25%       69.00
# 50%      126.00
# 75%      185.00
# max     1112.00
# Name: Active_Market_Wallets, dtype: float64

# %%
dataset = dataset[~((dataset['Active_Market_Wallets'] < (q1 - 1.5 * IR)) |(dataset['Active_Market_Wallets'] > (q3 + 1.5 * IR)))
# Out:
#   Input In [184]
#     dataset = dataset[~((dataset['Active_Market_Wallets'] < (q1 - 1.5 * IR)) |(dataset['Active_Market_Wallets'] > (q3 + 1.5 * IR)))
#                                                                                                                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
dataset.describe()
# Out:
#          Sales_USD  Number_of_Sales  Active_Market_Wallets  Primary_Sales
# count      1604.00          1604.00                1597.00        1604.00
# mean    6380649.38          6872.06                 176.06        4120.33
# std    24866794.69         12612.25                 207.58        7580.10
# min           0.00             0.00                -573.00           0.00
# 25%       46085.53          2279.25                  69.00        1462.75
# 50%       82227.25          3683.50                 126.00        2358.50
# 75%      352914.58          5844.50                 185.00        3698.00
# max   388636358.49        161732.00                1112.00       93609.00

# %%
dataset
# Out:
#             Date   Sales_USD  Number_of_Sales  Active_Market_Wallets  Primary_Sales
# 1     2017-06-23     1020.30            19.00                   8.00           0.00
# 2     2017-06-24     1240.84            21.00                  13.00           0.00
# 3     2017-06-25      517.55            13.00                   7.00           0.00
# 4     2017-06-26      424.63            14.00                   6.00           0.00
# 5     2017-06-27     2092.91            33.00                  10.00           0.00
# ...          ...         ...              ...                    ...            ...
# 1593  2021-10-31 66341039.65         53472.00                 126.00       35765.00
# 1594  2021-11-01 35538771.29         13646.00                 126.00       12106.00
# 1595  2021-11-02 82613309.89         67388.00                 126.00       46997.00
# 1596  2021-11-03 43099329.76         23465.00                 126.00       22022.00
# ...

# %%
pip install pymongo
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dnspython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo[srv]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing Mongoclient from pymongo
from pymongo import MongoClient

 
myclient = MongoClient("mongodb+srv://soumaya:soumaya1Atlas@cluster0.y9xab.mongodb.net/test?retryWrites=true&w=majority")
 
# database
db = myclient["DjangoDB"]
 
# Created or Switched to collection
# names: GeeksForGeeks
collection = db["NFT_sales"]

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-01.y9xab.mongodb.net:27017', 'cluster0-shard-00-02.y9xab.mongodb.net:27017', 'cluster0-shard-00-00.y9xab.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-qjddlr-shard-0', tls=True), 'DjangoDB'), 'NFT_sales')

# %%
dataset.to_dict()
# Out:
# {'Date': {1: '2017-06-23',
#   2: '2017-06-24',
#   3: '2017-06-25',
#   4: '2017-06-26',
#   5: '2017-06-27',
#   6: '2017-06-28',
#   7: '2017-06-29',
#   8: '2017-06-30',
#   9: '2017-07-01',
#   10: '2017-07-02',
#   11: '2017-07-03',
#   12: '2017-07-04',
#   13: '2017-07-05',
#   14: '2017-07-06',
#   15: '2017-07-07',
#   16: '2017-07-08',
#   17: '2017-07-09',
#   18: '2017-07-10',
#   19: '2017-07-11',
#   20: '2017-07-12',
#   21: '2017-07-13',
#   22: '2017-07-14',
#   23: '2017-07-15',
#   24: '2017-07-16',
#   25: '2017-07-17',
#   26: '2017-07-18',
#   27: '2017-07-19',
#   28: '2017-07-20',
#   29: '2017-07-21',
#   30: '2017-07-22',
#   31: '2017-07-23',
#   32: '2017-07-24',
#   33: '2017-07-25',
#   34: '2017-07-26',
#   35: '2017-07-27',
#   36: '2017-07-28',
#   37: '2017-07-29',
#   38: '2017-07-30',
#   39: '2017-07-31',
#   40: '2017-08-01',
#   41: '2017-08-02',
#   42: '2017-08-03',
#   43: '2017-08-04',
#   44: '2017-08-05',
#   45: '2017-08-06',
# ...

# %%
import json
records = json.loads(dataset.to_json(orient='records'))

# %%
records
# Out:
# [{'Date': '2017-06-23',
#   'Sales_USD': 1020.3,
#   'Number_of_Sales': 19.0,
#   'Active_Market_Wallets': 8.0,
#   'Primary_Sales': 0.0},
#  {'Date': '2017-06-24',
#   'Sales_USD': 1240.84,
#   'Number_of_Sales': 21.0,
#   'Active_Market_Wallets': 13.0,
#   'Primary_Sales': 0.0},
#  {'Date': '2017-06-25',
#   'Sales_USD': 517.55,
#   'Number_of_Sales': 13.0,
#   'Active_Market_Wallets': 7.0,
#   'Primary_Sales': 0.0},
#  {'Date': '2017-06-26',
#   'Sales_USD': 424.63,
#   'Number_of_Sales': 14.0,
#   'Active_Market_Wallets': 6.0,
#   'Primary_Sales': 0.0},
#  {'Date': '2017-06-27',
#   'Sales_USD': 2092.91,
#   'Number_of_Sales': 33.0,
#   'Active_Market_Wallets': 10.0,
#   'Primary_Sales': 0.0},
#  {'Date': '2017-06-28',
#   'Sales_USD': 1247.26,
#   'Number_of_Sales': 15.0,
#   'Active_Market_Wallets': 2.0,
#   'Primary_Sales': 0.0},
#  {'Date': '2017-06-29',
#   'Sales_USD': 2185.72,
#   'Number_of_Sales': 38.0,
#   'Active_Market_Wallets': 3.0,
#   'Primary_Sales': 0.0},
# ...

# %%
collection.insert_many(records)

# %%
for x in collection.find():
    print(x)
# Out:
# {'_id': ObjectId('6268113b0b68d1050c613288'), 'Date': '2017-06-23', 'Sales_USD': 1020.3, 'Number_of_Sales': 19.0, 'Active_Market_Wallets': 8.0, 'Primary_Sales': 0.0}
# {'_id': ObjectId('6268113b0b68d1050c613289'), 'Date': '2017-06-24', 'Sales_USD': 1240.84, 'Number_of_Sales': 21.0, 'Active_Market_Wallets': 13.0, 'Primary_Sales': 0.0}
# {'_id': ObjectId('6268113b0b68d1050c61328a'), 'Date': '2017-06-25', 'Sales_USD': 517.55, 'Number_of_Sales': 13.0, 'Active_Market_Wallets': 7.0, 'Primary_Sales': 0.0}
# {'_id': ObjectId('6268113b0b68d1050c61328b'), 'Date': '2017-06-26', 'Sales_USD': 424.63, 'Number_of_Sales': 14.0, 'Active_Market_Wallets': 6.0, 'Primary_Sales': 0.0}
# {'_id': ObjectId('6268113b0b68d1050c61328c'), 'Date': '2017-06-27', 'Sales_USD': 2092.91, 'Number_of_Sales': 33.0, 'Active_Market_Wallets': 10.0, 'Primary_Sales': 0.0}
# ...
