# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk import flatten
from sklearn import preprocessing

# %matplotlib inline

# %%
pd.options.display.float_format = '{:.4f}'.format
pd.set_option('display.width',2000)

# %% [markdown]
# # NFTs

# %%
df_nfts = pd.read_excel(r'C:\Users\Pc\Documents\Study\MST\S2\NoSQL\mod_nfts.xlsx',sheet_name='nft')
df_nfts
# Out:
#                   name      collection  last price currency blockchain
# 0     CryptoPunk #5217     CryptoPunks   2250.0000      eth   ethereum
# 1     CryptoPunk #8857     CryptoPunks   2000.0000      eth   ethereum
# 2     CryptoPunk #7252     CryptoPunks   1600.0000      eth   ethereum
# 3     CryptoPunk #2140     CryptoPunks   1600.0000      eth   ethereum
# 4     CryptoPunk #2338     CryptoPunks   1500.0000      eth   ethereum
# ..                 ...             ...         ...      ...        ...
# 953          Ouch Baby  ZED RUN Legacy     77.0000      eth    polygon
# 954  Its Gonna Be Huge  ZED RUN Legacy     63.1100      eth    polygon
# 955         Stay Close  ZED RUN Legacy     63.1100      eth    polygon
# 956       Star Strider  ZED RUN Legacy     58.0000      eth    polygon
# 957   Chromatic Theory  ZED RUN Legacy     42.0000      eth    polygon
#
# [958 rows x 5 columns]

# %%
df_nfts.rename(columns = {'last price':'last_price'}, inplace = True)

# %%
############Label encoding###############
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'collection'.
df_nfts['id_collection']= label_encoder.fit_transform(df_nfts['collection'])
  
df_nfts['collection'].unique()
# Out:
# array(['CryptoPunks', 'The Sandbox', 'Cool Cats NFT',
#        'Bored Ape Kennel Club', 'CryptoKitties', 'CrypToadz by GREMPLIN',
#        'World of Women', 'Loot (for Adventurers)', 'Rarible', 'Doodles',
#        'Meebits', 'Moonbirds', 'Otherdeed for Otherside',
#        'CLONE X - X TAKASHI MURAKAMI', 'Decentraland', 'Azuki',
#        'Bored Ape Yacht Club', 'Mutant Ape Yacht Club',
#        'Degenerate Ape Academy', 'Stoned Ape Crew',
#        'Famous Fox Federation', 'MOUS IN DA HOUS', 'The Suites',
#        'Dazed Ducks', 'SOLgods', 'Space Runners', 'Blocksmith Labs',
#        'TombStoned High Society', 'ASTRALS', 'Shadowy Super Coder',
#        'Communi3: Mad Scientists', 'The Catalina Whale Mixer', 'Portals',
#        'DeGods', 'Cets on Creck', 'Okay Bears', 'DeRace Horses',
#        'Crypto Raiders Characters', 'The Red Village Champions',
#        'Brave Frontier Heroes', 'Crypto Unicorns Shadowcorns',
#        'The Martians: Metaverse', 'Ethermon', 'Genesis Curry Flow',
#        'Chumbi Valley Official', 'Ember Sword Land', 'PolkaPets TCG',
#        'Crypto Unicorns Market', 'BCCG', 'Chicken Derby',
#        'MyCryptoHeroes', 'Crypto Unicorns Land Market',
#        'Decentral Games ICE Poker', 'ZED RUN Legacy'], dtype=object)

# %%
df_nfts['blockchain']=df_nfts['blockchain'].map({'ethereum':1,'solana':2,'polygon':3})

# %%
eth=df_nfts.loc[df_nfts['blockchain'] == 1, 'currency']
pol=df_nfts.loc[df_nfts['blockchain'] == 3, 'currency']
sol=df_nfts.loc[df_nfts['blockchain'] == 2, 'currency']

# %%
df_nfts['currency'].loc[df_nfts['blockchain'] == 1]=eth.map({'eth':11,'SAND':12,'USDC':13,'weth':14,'MANA':15})
df_nfts['currency'].loc[df_nfts['blockchain'] == 2]=sol.map({'sol':2})
df_nfts['currency'].loc[df_nfts['blockchain'] == 3]=pol.map({'eth':31,'weth':32})
############!-Label encoding###############
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_18820\1551878445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nfts['currency'].loc[df_nfts['blockchain'] == 1]=eth.map({'eth':11,'SAND':12,'USDC':13,'weth':14,'MANA':15})
# C:\Users\Pc\AppData\Local\Temp\ipykernel_18820\1551878445.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nfts['currency'].loc[df_nfts['blockchain'] == 2]=sol.map({'sol':2})
# C:\Users\Pc\AppData\Local\Temp\ipykernel_18820\1551878445.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nfts['currency'].loc[df_nfts['blockchain'] == 3]=pol.map({'eth':31,'weth':32})

# %%
df_nfts['id'] = range(1, len(df_nfts) + 1)

# %%
df_nfts
# Out:
#                   name      collection  last price currency blockchain   id
# 0     CryptoPunk #5217     CryptoPunks   2250.0000      eth   ethereum    1
# 1     CryptoPunk #8857     CryptoPunks   2000.0000      eth   ethereum    2
# 2     CryptoPunk #7252     CryptoPunks   1600.0000      eth   ethereum    3
# 3     CryptoPunk #2140     CryptoPunks   1600.0000      eth   ethereum    4
# 4     CryptoPunk #2338     CryptoPunks   1500.0000      eth   ethereum    5
# ..                 ...             ...         ...      ...        ...  ...
# 953          Ouch Baby  ZED RUN Legacy     77.0000      eth    polygon  954
# 954  Its Gonna Be Huge  ZED RUN Legacy     63.1100      eth    polygon  955
# 955         Stay Close  ZED RUN Legacy     63.1100      eth    polygon  956
# 956       Star Strider  ZED RUN Legacy     58.0000      eth    polygon  957
# 957   Chromatic Theory  ZED RUN Legacy     42.0000      eth    polygon  958
#
# [958 rows x 6 columns]

# %%
df_nfts['last_price'].dtypes
# Out:
# dtype('float64')

# %%
df_nfts['last_price'].describe()
# Out:
# count              958.0000
# mean      104387528911.8860
# std      3230853240531.4893
# min                  0.0001
# 25%                 10.0000
# 50%                112.7500
# 75%                399.0000
# max     99999999999999.0000
# Name: last_price, dtype: float64

# %%
def detect_outliers_iqr(data):
    outliers = []
    data = sorted(data)
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    IQR = q3-q1
    lwr_bound = q1-(1.5*IQR)
    upr_bound = q3+(1.5*IQR)
    for i in data: 
        if (i<lwr_bound or i>upr_bound):
            outliers.append(i)
    return outliers

# %%
num_outliers=len(detect_outliers_iqr(df_nfts['last_price']))
print(num_outliers)
print(df_nfts.shape[0])
# Out:
# 114
# 958

# %%
pourcentage_oultiers = num_outliers/df_nfts.shape[0]
print(pourcentage_oultiers*100)
# Out:
# 11.899791231732777

# %%
def replace_outliers(data):
    nfts_outliers = detect_outliers_iqr(data)
    print("The before : Outliers from IQR method: ", nfts_outliers)
    # Computing 10th, 90th percentiles and replacing the outliers
    # tenth_percentile = np.percentile(data, 10)
    # ninetieth_percentile = np.percentile(data, 90)
    # print(ninetieth_percentile)
    # data= np.where(data<tenth_percentile, tenth_percentile, data)
    # data = np.where(data>ninetieth_percentile, ninetieth_percentile, data)

    median = np.median(data)# Replace with median
    print('median ',median)
    for outlier in detect_outliers_iqr(data):
        data = np.where(data==outlier, median, data)
    return data

# %%
collections = df_nfts['collection'].unique()
new_last_price = []
for col in collections:
    grp=df_nfts.loc[df_nfts['collection'] == col]
    print(grp['collection'].unique()[0])
    grp['last_price']=replace_outliers(grp['last_price'])
    nfts_outliers = detect_outliers_iqr(grp['last_price'])
    print("After replacing outliers : Outliers from IQR method: ", nfts_outliers)
    print('\n')
    new_last_price.append(grp['last_price'].tolist())
# Out:
# CryptoPunks
# The before : Outliers from IQR method:  [8000.0, 124457.0675]
# median  1600.0
# C:\Users\Pc\AppData\Local\Temp\ipykernel_824\1804702071.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grp['last_price']=replace_outliers(grp['last_price'])
# After replacing outliers : Outliers from IQR method:  [4200.0, 4200.0]
#
#
# The Sandbox
# The before : Outliers from IQR method:  [3644834.6103]
# median  368679.41875
# After replacing outliers : Outliers from IQR method:  []
#
#
# Cool Cats NFT
# The before : Outliers from IQR method:  []
# median  350.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# Bored Ape Kennel Club
# The before : Outliers from IQR method:  [19857.0, 50000.0]
# median  169.0
# After replacing outliers : Outliers from IQR method:  [700.0, 4390.0, 5000.0, 9999.0]
#
#
# CryptoKitties
# The before : Outliers from IQR method:  [600.0, 600000.0]
# median  184.56009999999998
# After replacing outliers : Outliers from IQR method:  []
#
#
# CrypToadz by GREMPLIN
# The before : Outliers from IQR method:  [1000.0, 1111.1111, 6969.6969]
# median  100.0
# After replacing outliers : Outliers from IQR method:  [69.69, 69.69, 77.77, 142.69, 369.0, 500.0]
#
#
# World of Women
# The before : Outliers from IQR method:  [2323.0, 10069.0]
# median  562.345
# After replacing outliers : Outliers from IQR method:  []
#
#
# Loot (for Adventurers)
# The before : Outliers from IQR method:  []
# median  167.0505
# After replacing outliers : Outliers from IQR method:  []
#
#
# Rarible
# The before : Outliers from IQR method:  [13371337.0, 71500000.0, 3133731337.0, 99999999999999.0]
# median  31337.0
# After replacing outliers : Outliers from IQR method:  [1000000.0]
#
#
# Doodles
# The before : Outliers from IQR method:  [2500.0, 4200.0, 5000.0]
# median  683.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# Meebits
# The before : Outliers from IQR method:  [8888.0]
# median  777.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# Moonbirds
# The before : Outliers from IQR method:  [350.0]
# median  132.5
# After replacing outliers : Outliers from IQR method:  [305.0]
#
#
# Otherdeed for Otherside
# The before : Outliers from IQR method:  [50000.0]
# median  245.53449999999998
# After replacing outliers : Outliers from IQR method:  []
#
#
# CLONE X - X TAKASHI MURAKAMI
# The before : Outliers from IQR method:  [450.0]
# median  199.345
# After replacing outliers : Outliers from IQR method:  []
#
#
# Decentraland
# The before : Outliers from IQR method:  [2772000.0]
# median  1200000.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# Azuki
# The before : Outliers from IQR method:  [1690.42, 1888.0, 9999.0]
# median  939.5
# After replacing outliers : Outliers from IQR method:  []
#
#
# Bored Ape Yacht Club
# The before : Outliers from IQR method:  []
# median  427.5
# After replacing outliers : Outliers from IQR method:  []
#
#
# Mutant Ape Yacht Club
# The before : Outliers from IQR method:  [222.0, 250.0, 335.0, 350.0]
# median  111.25
# After replacing outliers : Outliers from IQR method:  []
#
#
# Degenerate Ape Academy
# The before : Outliers from IQR method:  [1200.0]
# median  399.495
# After replacing outliers : Outliers from IQR method:  []
#
#
# Stoned Ape Crew
# The before : Outliers from IQR method:  [242.0, 300.0, 420.0]
# median  136.21035
# After replacing outliers : Outliers from IQR method:  [169.0, 169.0, 170.0]
#
#
# Famous Fox Federation
# The before : Outliers from IQR method:  [188.0, 190.0, 300.0]
# median  94.5
# After replacing outliers : Outliers from IQR method:  []
#
#
# MOUS IN DA HOUS
# The before : Outliers from IQR method:  [99.0]
# median  39.870000000000005
# After replacing outliers : Outliers from IQR method:  []
#
#
# The Suites
# The before : Outliers from IQR method:  [420.0]
# median  244.5
# After replacing outliers : Outliers from IQR method:  [340.0]
#
#
# Dazed Ducks
# The before : Outliers from IQR method:  [300.0]
# median  53.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# SOLgods
# The before : Outliers from IQR method:  [300.0]
# median  115.5
# After replacing outliers : Outliers from IQR method:  [175.0]
#
#
# Space Runners
# The before : Outliers from IQR method:  [200.0, 200.0, 205.0, 266.8]
# median  97.5
# After replacing outliers : Outliers from IQR method:  [72.98, 115.0]
#
#
# Blocksmith Labs
# The before : Outliers from IQR method:  [135.333]
# median  110.5
# After replacing outliers : Outliers from IQR method:  [98.0, 98.0, 130.0, 130.0]
#
#
# TombStoned High Society
# The before : Outliers from IQR method:  [69.0, 100.0]
# median  36.675
# After replacing outliers : Outliers from IQR method:  []
#
#
# ASTRALS
# The before : Outliers from IQR method:  [300.0]
# median  69.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# Shadowy Super Coder
# The before : Outliers from IQR method:  []
# median  191.5
# After replacing outliers : Outliers from IQR method:  []
#
#
# Communi3: Mad Scientists
# The before : Outliers from IQR method:  [240.0, 300.0, 300.0]
# median  100.0
# After replacing outliers : Outliers from IQR method:  [120.0, 126.969, 150.0, 215.69]
#
#
# The Catalina Whale Mixer
# The before : Outliers from IQR method:  [500.0, 696.9]
# median  200.0
# After replacing outliers : Outliers from IQR method:  [169.0, 250.0, 250.0, 300.0]
#
#
# Portals
# The before : Outliers from IQR method:  []
# median  472.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# DeGods
# The before : Outliers from IQR method:  []
# median  552.5
# After replacing outliers : Outliers from IQR method:  []
#
#
# Cets on Creck
# The before : Outliers from IQR method:  [300.0]
# median  200.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# Okay Bears
# The before : Outliers from IQR method:  []
# median  895.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# DeRace Horses
# The before : Outliers from IQR method:  [17.97, 23.0, 24.99]
# median  10.3
# After replacing outliers : Outliers from IQR method:  [14.99]
#
#
# Crypto Raiders Characters
# The before : Outliers from IQR method:  [5.0, 17.95]
# median  2.8
# After replacing outliers : Outliers from IQR method:  []
#
#
# The Red Village Champions
# The before : Outliers from IQR method:  [7.77, 8.0]
# median  5.0
# After replacing outliers : Outliers from IQR method:  [6.0, 6.25]
#
#
# Brave Frontier Heroes
# The before : Outliers from IQR method:  [4.3, 4.8]
# median  3.6
# After replacing outliers : Outliers from IQR method:  [4.2]
#
#
# Crypto Unicorns Shadowcorns
# The before : Outliers from IQR method:  [16.0]
# median  0.0917
# After replacing outliers : Outliers from IQR method:  []
#
#
# The Martians: Metaverse
# The before : Outliers from IQR method:  [3.5, 5.5]
# median  2.6745
# After replacing outliers : Outliers from IQR method:  []
#
#
# Ethermon
# The before : Outliers from IQR method:  [2500.0, 2500.0, 2600.0]
# median  4.390000000000001
# After replacing outliers : Outliers from IQR method:  [7.49, 9.39]
#
#
# Genesis Curry Flow
# The before : Outliers from IQR method:  [1.25]
# median  0.14
# After replacing outliers : Outliers from IQR method:  [0.085, 0.2395]
#
#
# Chumbi Valley Official
# The before : Outliers from IQR method:  [8.0, 8.5, 9.7]
# median  5.3149999999999995
# After replacing outliers : Outliers from IQR method:  [5.9, 6.0, 6.55]
#
#
# Ember Sword Land
# The before : Outliers from IQR method:  [30.0, 30.0, 35.0]
# median  15.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# PolkaPets TCG
# The before : Outliers from IQR method:  [0.2, 0.5]
# median  0.0315
# After replacing outliers : Outliers from IQR method:  [0.097]
#
#
# Crypto Unicorns Market
# The before : Outliers from IQR method:  []
# median  9.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# BCCG
# The before : Outliers from IQR method:  [0.42, 1.0, 9.95]
# median  0.1505
# After replacing outliers : Outliers from IQR method:  [0.249]
#
#
# Chicken Derby
# The before : Outliers from IQR method:  [7.5, 8.0, 9.0]
# median  4.5
# After replacing outliers : Outliers from IQR method:  [5.5]
#
#
# MyCryptoHeroes
# The before : Outliers from IQR method:  []
# median  35.0
# After replacing outliers : Outliers from IQR method:  []
#
#
# Crypto Unicorns Land Market
# The before : Outliers from IQR method:  [3.69]
# median  1.7494
# After replacing outliers : Outliers from IQR method:  []
#
#
# Decentral Games ICE Poker
# The before : Outliers from IQR method:  [7.0]
# median  5.475
# After replacing outliers : Outliers from IQR method:  []
#
#
# ZED RUN Legacy
# The before : Outliers from IQR method:  [110.0]
# median  36.25
# After replacing outliers : Outliers from IQR method:  [58.0, 63.11, 63.11, 77.0]

# %%
new_last_price = flatten(new_last_price)
print(new_last_price)
# Out:
# [2250.0, 2000.0, 1600.0, 1600.0, 1500.0, 1319.0, 1180.0, 1050.0, 900.0, 888.8, 850.0, 810.0, 1600.0, 1600.0, 4200.0, 4200.0, 2501.0, 2500.0, 650000.0, 484987.0, 380000.0, 357358.8375, 308700.0, 289800.0, 240042.0, 235000.0, 220000.0, 210000.0, 120.0, 168000.0, 368679.41875, 700000.0, 580000.0, 530000.0, 525000.0, 500000.0, 420.69, 420.69, 400.0, 300.0, 150.0, 125.0, 120.0, 100.0, 100.0, 100.0, 100.0, 100.0, 1000.0, 1000.0, 888.888, 888.0, 500.0, 420.69, 200.0, 169.0, 169.0, 150.0, 150.0, 104.25, 100.0, 100.0, 99.99, 88.0, 88.0, 169.0, 9999.0, 5000.0, 4390.0, 700.0, 299.0, 222.0, 184.56009999999998, 190.0468, 179.0734, 177.0, 175.7532, 168.6849, 156.87, 154.0, 153.559, 150.0, 150.0, 184.56009999999998, 253.3368, 247.0, 246.9255, 225.0, 225.0, 125.0, 111.0, 100.0, 100.0, 100.0, 100.0, 100.0, 95.0, 84.2069, 77.77, 69.69, 69.69, 100.0, 100.0, 100.0, 500.0, 369.0, 142.69, 725.0, 696.969, 569.69, 555.0, 555.0, 528.0, 500.0, 444.0, 444.0, 444.0, 444.0, 333.0, 562.345, 562.345, 1000.0, 999.99, 888.0, 777.0, 256.0, 250.0, 180.0, 154.101, 123.0, 120.0, 109.0, 103.0, 101.01, 100.01, 99.99, 546.0, 500.0, 420.69, 300.0, 288.0, 269.69, 96.69, 0.0003, 31337.0, 31337.0, 31337.0, 31337.0, 31337.0, 31337.0, 31337.0, 1000000.0, 18000.0, 11500.0, 0.02, 31337.0, 0.001, 31337.0, 0.002, 0.0001, 0.001, 999.0, 969.69, 700.0, 666.0, 555.55, 500.0, 500.0, 420.69, 420.0, 420.0, 388.0, 360.0, 683.0, 683.0, 683.0, 1420.69, 1000.0, 1000.0, 888.0, 800.0, 777.0, 777.0, 750.0, 715.0, 700.0, 642.0, 500.0, 360.0, 350.0, 333.0, 777.0, 1002.0, 999.888, 999.0, 900.0, 899.0, 175.0, 150.0, 135.0, 130.0, 130.0, 125.0, 125.0, 120.0, 118.0, 110.0, 100.0, 100.0, 132.5, 305.0, 300.0, 299.0, 205.0, 199.0, 250.0, 249.0, 242.069, 235.0, 232.0, 225.0, 204.96, 245.53449999999998, 199.0, 195.0, 190.0, 190.0, 333.33, 333.0, 300.0, 290.0, 280.0, 250.0, 250.0, 200.0, 199.69, 199.0, 190.0, 185.0, 177.0, 175.0, 175.0, 175.0, 175.0, 165.0, 199.345, 368.0, 302.0, 289.0, 288.0, 270.0, 1300000.0, 1295000.0, 1250000.0, 1150000.0, 1120000.0, 1000000.0, 850000.0, 759361.0, 750000.0, 735000.0, 695000.0, 669000.0, 1200000.0, 2000000.0, 1400000.0, 1400000.0, 1300000.0, 1299999.0, 999.0, 999.0, 999.0, 880.0, 850.0, 695.4, 666.0, 666.0, 588.0, 500.0, 420.69, 420.69, 939.5, 939.5, 939.5, 1111.0, 1000.0, 999.0, 500.0, 500.0, 430.0, 425.0, 425.0, 420.69, 420.0, 410.0, 400.0, 388.8, 347.0, 301.0, 769.0, 740.0, 666.0, 600.0, 569.0, 550.0, 115.0, 115.0, 112.5, 110.0, 100.0, 99.0, 95.0, 90.0, 89.0, 88.8, 88.0, 80.69, 111.25, 111.25, 111.25, 111.25, 120.0, 120.0, 599.0, 399.99, 399.0, 469.69, 335.69, 309.0, 300.0, 300.0, 280.0, 280.0, 279.69, 260.0, 399.495, 698.0277, 800.0, 770.0, 615.0, 550.0, 155.0, 142.0, 142.069, 130.4207, 125.42, 127.0, 124.42, 124.95, 125.0, 122.222, 120.42, 120.0, 136.21035, 136.21035, 136.21035, 169.0, 169.0, 170.0, 100.0, 99.0, 99.0, 90.0, 88.0, 80.0, 79.99, 77.0, 75.0, 80.0, 80.0, 80.0, 94.5, 94.5, 94.5, 120.0, 125.0, 99.0, 53.0, 42.0, 40.0, 39.74, 36.5, 38.99, 33.33, 35.0, 30.0, 30.0, 29.99, 29.99, 39.870000000000005, 80.0, 80.0, 64.44, 60.0, 55.0, 250.0, 250.0, 245.0, 244.0, 240.69, 225.0, 210.0, 210.0, 205.0, 205.0, 200.0, 200.0, 244.5, 340.0, 310.0, 300.0, 290.69, 259.0, 69.69, 55.0, 55.0, 51.0, 50.0, 49.99, 42.0, 39.0, 38.0, 37.0, 36.0, 35.0, 53.0, 99.99, 84.0, 75.0, 69.4207, 65.0, 121.0, 120.0, 125.0, 111.0, 110.0, 110.0, 100.0, 100.0, 100.0, 100.0, 100.0, 90.0, 115.5, 175.0, 150.0, 145.0, 141.0, 126.9, 109.0, 100.0, 100.0, 95.0, 90.22, 91.0, 90.0, 89.999, 88.0, 86.5, 77.0, 72.98, 97.5, 97.5, 97.5, 97.5, 115.0, 112.0, 120.0, 120.0, 115.0, 114.0, 113.0, 111.0, 110.0, 110.0, 110.0, 110.0, 108.0, 108.0, 110.5, 100.69, 130.0, 98.0, 98.0, 130.0, 39.69, 38.0, 36.69, 36.66, 35.0, 35.0, 35.0, 35.0, 34.9, 34.69, 34.0, 33.33, 36.675, 36.675, 42.0, 40.0, 40.0, 40.0, 88.0, 77.0, 75.0, 63.0, 60.0, 54.2, 52.0, 50.0, 50.0, 55.0, 50.0, 50.0, 69.0, 150.0, 133.3333, 100.0, 100.0, 99.0, 195.0, 235.0, 188.0, 180.0, 205.0, 175.0, 167.0, 167.0, 166.9, 165.0, 165.0, 165.0, 228.0, 229.0, 250. ...

# %%
df_nfts['last_price']=new_last_price

# %%
grp1=df_nfts.loc[df_nfts['collection'] == 'CryptoPunks']
plt.figure(figsize =(10, 10))
plot=grp1.boxplot(['last_price'])
nfts_outliers1 = detect_outliers_iqr(grp1['last_price'])
print("Outliers from IQR method: ", nfts_outliers1)
# Out:
# Outliers from IQR method:  [4200.0, 4200.0]

# %%
for col in collections:
    grp=df_nfts.loc[df_nfts['collection'] == col]
    nfts_outliers = detect_outliers_iqr(grp['last_price'])
    print("Outliers from IQR method: ", nfts_outliers)
# Out:
# Outliers from IQR method:  [4200.0, 4200.0]
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  [700.0, 4390.0, 5000.0, 9999.0]
# Outliers from IQR method:  []
# Outliers from IQR method:  [69.69, 69.69, 77.77, 142.69, 369.0, 500.0]
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  [1000000.0]
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  [305.0]
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  [169.0, 169.0, 170.0]
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  [340.0]
# Outliers from IQR method:  []
# Outliers from IQR method:  [175.0]
# Outliers from IQR method:  [72.98, 115.0]
# Outliers from IQR method:  [98.0, 98.0, 130.0, 130.0]
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  [120.0, 126.969, 150.0, 215.69]
# Outliers from IQR method:  [169.0, 250.0, 250.0, 300.0]
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  [14.99]
# Outliers from IQR method:  []
# Outliers from IQR method:  [6.0, 6.25]
# Outliers from IQR method:  [4.2]
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  [7.49, 9.39]
# Outliers from IQR method:  [0.085, 0.2395]
# Outliers from IQR method:  [5.9, 6.0, 6.55]
# Outliers from IQR method:  []
# Outliers from IQR method:  [0.097]
# Outliers from IQR method:  []
# Outliers from IQR method:  [0.249]
# Outliers from IQR method:  [5.5]
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  []
# Outliers from IQR method:  [58.0, 63.11, 63.11, 77.0]

# %%
df_nfts['last_price'].describe()
# Out:
# count       958.0000
# mean      29708.8556
# std      170604.8363
# min           0.0001
# 25%           9.0832
# 50%         103.6250
# 75%         333.0000
# max     2000000.0000
# Name: last_price, dtype: float64

# %%
df_nfts.isnull().sum()
# Out:
# name          0
# collection    0
# last_price    0
# currency      0
# blockchain    0
# dtype: int64

# %%
df_nfts['last_price'].mode()
# Out:
# 0   100.0000
# Name: last_price, dtype: float64

# %%
df_nfts
# Out:
#                   name      collection  last_price currency blockchain   id
# 0     CryptoPunk #5217     CryptoPunks   2250.0000      eth   ethereum    1
# 1     CryptoPunk #8857     CryptoPunks   2000.0000      eth   ethereum    2
# 2     CryptoPunk #7252     CryptoPunks   1600.0000      eth   ethereum    3
# 3     CryptoPunk #2140     CryptoPunks   1600.0000      eth   ethereum    4
# 4     CryptoPunk #2338     CryptoPunks   1500.0000      eth   ethereum    5
# ..                 ...             ...         ...      ...        ...  ...
# 953          Ouch Baby  ZED RUN Legacy     77.0000      eth    polygon  954
# 954  Its Gonna Be Huge  ZED RUN Legacy     63.1100      eth    polygon  955
# 955         Stay Close  ZED RUN Legacy     63.1100      eth    polygon  956
# 956       Star Strider  ZED RUN Legacy     58.0000      eth    polygon  957
# 957   Chromatic Theory  ZED RUN Legacy     42.0000      eth    polygon  958
#
# [958 rows x 6 columns]

# %%
df_nfts.duplicated().sum()
# Out:
# 0

# %%
df_nfts.loc[df_nfts.duplicated(), :]
# Out:
# Empty DataFrame
# Columns: [name, collection, last_price, currency, blockchain, id]
# Index: []

# %%
df_nfts.drop_duplicates(inplace=True)

# %%
df_nfts.duplicated().sum()
# Out:
# 0

# %%
df_nfts
# Out:
#                   name      collection  last_price currency blockchain   id
# 0     CryptoPunk #5217     CryptoPunks   2250.0000      eth   ethereum    1
# 1     CryptoPunk #8857     CryptoPunks   2000.0000      eth   ethereum    2
# 2     CryptoPunk #7252     CryptoPunks   1600.0000      eth   ethereum    3
# 3     CryptoPunk #2140     CryptoPunks   1600.0000      eth   ethereum    4
# 4     CryptoPunk #2338     CryptoPunks   1500.0000      eth   ethereum    5
# ..                 ...             ...         ...      ...        ...  ...
# 953          Ouch Baby  ZED RUN Legacy     77.0000      eth    polygon  954
# 954  Its Gonna Be Huge  ZED RUN Legacy     63.1100      eth    polygon  955
# 955         Stay Close  ZED RUN Legacy     63.1100      eth    polygon  956
# 956       Star Strider  ZED RUN Legacy     58.0000      eth    polygon  957
# 957   Chromatic Theory  ZED RUN Legacy     42.0000      eth    polygon  958
#
# [958 rows x 6 columns]

# %% [markdown]
# # Collections

# %%
ids=df_nfts['id_collection'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\users\pc\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\users\pc\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\users\pc\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id_collection'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 ids=df_nfts['id_collection'].unique()
#
# File c:\users\pc\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\users\pc\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'id_collection'

# %%
cols=df_nfts['collection'].unique()

# %%
dic = dict(zip(ids, cols))

# %%
dic
# Out:
# {19: 'CryptoPunks',
#  49: 'The Sandbox',
#  12: 'Cool Cats NFT',
#  4: 'Bored Ape Kennel Club',
#  18: 'CryptoKitties',
#  13: 'CrypToadz by GREMPLIN',
#  52: 'World of Women',
#  31: 'Loot (for Adventurers)',
#  41: 'Rarible',
#  26: 'Doodles',
#  33: 'Meebits',
#  34: 'Moonbirds',
#  38: 'Otherdeed for Otherside',
#  7: 'CLONE X - X TAKASHI MURAKAMI',
#  24: 'Decentraland',
#  1: 'Azuki',
#  5: 'Bored Ape Yacht Club',
#  35: 'Mutant Ape Yacht Club',
#  25: 'Degenerate Ape Academy',
#  45: 'Stoned Ape Crew',
#  29: 'Famous Fox Federation',
#  32: 'MOUS IN DA HOUS',
#  50: 'The Suites',
#  20: 'Dazed Ducks',
#  42: 'SOLgods',
#  44: 'Space Runners',
#  3: 'Blocksmith Labs',
#  51: 'TombStoned High Society',
#  0: 'ASTRALS',
#  43: 'Shadowy Super Coder',
#  11: 'Communi3: Mad Scientists',
#  46: 'The Catalina Whale Mixer',
#  40: 'Portals',
#  21: 'DeGods',
#  8: 'Cets on Creck',
#  37: 'Okay Bears',
#  22: 'DeRace Horses',
#  14: 'Crypto Raiders Characters',
#  48: 'The Red Village Champions',
#  6: 'Brave Frontier Heroes',
#  17: 'Crypto Unicorns Shadowcorns',
#  47: 'The Martians: Metaverse',
#  28: 'Ethermon',
#  30: 'Genesis Curry Flow',
#  10: 'Chumbi Valley Official',
#  27: 'Ember Sword Land',
#  39: 'PolkaPets TCG',
#  16: 'Crypto Unicorns Market',
#  2: 'BCCG',
#  9: 'Chicken Derby',
#  36: 'MyCryptoHeroes',
#  15: 'Crypto Unicorns Land Market',
#  23: 'Decentral Games ICE Poker',
#  53: 'ZED RUN Legacy'}

# %%
df = pd.read_excel (r'C:\Users\Pc\Documents\Study\MST\S2\NoSQL\nfts.xlsx',sheet_name='collection')
df
# Out:
#                             name       volume floor price  Owners   items  \
# 0                    The Sandbox    152 791,7         1.7   21.7K  140.0K
# 1                  Cool Cats NFT   106 582,83        3.84    5.5K    9.9K
# 2          Bored Ape Kennel Club    98 360,89         7.4    5.5K    9.6K
# 3                  CryptoKitties    70 686,82       0.005  115.8K    2.0M
# 4          CrypToadz by GREMPLIN    69 469,78        2.09    4.2K    7.0K
# 5                 World of Women     68 943,1        4.68    5.4K   10.0K
# 6         Loot (for Adventurers)    74 393,59        0.95    2.6K    7.8K
# 7                        Rarible   100 833,34         ---  213.5K  315.5K
# 8                        Doodles   130 104,81        12.7    5.0K   10.0K
# 9                        Meebits   119 508,55         4.5    6.5K   20.0K
# 10                     Moonbirds   142 144,45       26.42    6.5K   10.0K
# 11       Otherdeed for Otherside   278 486,21         3.2   34.5K   98.6K
# 12  CLONE X - X TAKASHI MURAKAMI   202 596,11        14.5    9.3K   19.3K
# 13                  Decentraland   174 219,35        2.27    7.2K   97.5K
# 14                         Azuki   241 760,45          13    5.1K   10.0K
# 15          Bored Ape Yacht Club    576 677,8          94    6.3K   10.0K
# 16         Mutant Ape Yacht Club   401 784,97        18.2   12.5K   19.3K
# 17                   CryptoPunks   908 074,25         ---    3.5K   10.0K
# 18        Degenerate Ape Academy   138 887,04        64.9    4.3K   10.0K
# 19               Stoned Ape Crew    127 313,1        84.2    4.1K    4.2K
# 20         Famous Fox Federation   112 415,49          55    4.0K    7.8K
# 21               MOUS IN DA HOUS   104 316,47         8.4     799    4.4K
# 22                    The Suites    103 649,3          10    2.7K    4.9K
# 23                   Dazed Ducks   102 528,29         8.2    3.5K   10.0K
# 24                       SOLgods   108 030,36          50    1.1K    6.7K
# 25                 Space Runners   123 165,75          10    5.1K    9.8K
# 26               Blocksmith Labs   138 156,72         122    2.8K    4.4K
# 27       TombStoned High Society   136 385,83          15     855    6.6K
# 28                       ASTRALS   138 187,67          10    3.7K   10.0K
# 29           Shadowy Super Coder   228 400,45         ---     151   10.0K
# 30      Communi3: Mad Scientists   187 621,39        35.5    2.9K    5.0K
# 31      The Catalina Whale Mixer   167 323,29         ---    2.0K    5.6K
# 32                       Portals   199 462,77        54.5    2.9K    5.0K
# 33                        DeGods   513 557,49         340    4.3K   10.0K
# 34                 Cets on Creck   264 484,37          67    4.0K    7.0K
# 35                    Okay Bears  1 552 565,6         202    5.3K   10.0K
# 36                 DeRace Horses     3 541,13        0.09    1.9K    5.5K
# 37     Crypto Raiders Characters      2 282,3        0.01    4.5K   68.9K
# 38     The Red Village Champions     2 069,46        0.06    2.0K   11.0K
# 39         Brave Frontier Heroes     2 011,86       0.001    2.4K   20.1K
# 40   Crypto Unicorns Shadowcorns     1 834,28       0.002   15.5K      41
# 41       The Martians: Metaverse     1 788,42         0.6     762    5.0K
# 42                      Ethermon     2 012,55       0.004   65.5K  299.7K
# 43            Genesis Curry Flow     2 172,59         ---    2.2K       5
# 44        Chumbi Valley Official     3 100,75        0.18    1.8K    4.1K
# 45              Ember Sword Land     3 028,61         0.1    6.1K   40.0K
# 46                 PolkaPets TCG        3 483       0.006    4.6K      42
# 47        Crypto Unicorns Market     10 238,5         0.2    2.9K   18.8K
# 48                          BCCG     4 021,48        0.01    5.4K      58
# 49                 Chicken Derby     4 007,85        0.02    6.0K   33.3K
# 50   Crypto Unicorns Land Market     5 013,38        0.07    5.6K   30.0K
# 51                MyCryptoHeroes    27 229,22       0.002    5.8K   78.6K
# 52     Decentral Games ICE Poker    12 022,75        0.31    4.1K   33.2K
# 53                ZED RUN Legacy    46 708,63        0.01   36.2K  217.9K
#
#    blockchain currency
# 0    ethereum      eth
# 1    ethereum      eth
# 2    ethereum      eth
# 3    ethereum      eth
# 4    ethereum      eth
# 5    ethereum      eth
# 6    ethereum      eth
# 7    ethereum      eth
# 8    ethereum      eth
# 9    ethereum      eth
# 10   ethereum      eth
# 11   ethereum      eth
# 12   ethereum      eth
# 13   ethereum      eth
# 14   ethereum      eth
# 15   ethereum      eth
# 16   ethereum      eth
# 17   ethereum      eth
# 18     solana      sol
# 19     solana      sol
# 20     solana      sol
# 21     solana      sol
# 22     solana      sol
# 23     solana      sol
# 24     solana      sol
# 25     solana      sol
# 26     solana      sol
# 27     solana      sol
# 28     solana      sol
# 29     solana      sol
# 30     solana      sol
# 31     solana      sol
# 32     solana      sol
# 33     solana      sol
# 34     solana      sol
# 35     solana      sol
# 36    polygon      eth
# 37    polygon      eth
# 38    polygon      eth
# 39    polygon      eth
# 40    polygon      eth
# 41    polygon      eth
# 42    polygon      eth
# 43    polygon      eth
# 44    polygon      eth
# 45    polygon      eth
# 46    polygon      eth
# 47    polygon      eth
# 48    polygon      eth
# 49    polygon      eth
# 50    polygon      eth
# 51    polygon      eth
# 52    polygon      eth
# 53    polygon      eth

# %%
df['items']= df['items'].replace({'K': '*1e3','M': '*1e6'}, regex=True).map(pd.eval).astype(int) #replace K to numerical value
df['Owners']= df['Owners'].replace({'K': '*1e3'}, regex=True).map(pd.eval).astype(int)

df['floor price']= df["floor price"].replace(to_replace =["---"], value = 0) #replace missing value with 0

df
# Out:
#                             name       volume floor price  Owners    items  \
# 0                    The Sandbox    152 791,7         1.7   21700   140000
# 1                  Cool Cats NFT   106 582,83        3.84    5500     9900
# 2          Bored Ape Kennel Club    98 360,89         7.4    5500     9600
# 3                  CryptoKitties    70 686,82       0.005  115800  2000000
# 4          CrypToadz by GREMPLIN    69 469,78        2.09    4200     7000
# 5                 World of Women     68 943,1        4.68    5400    10000
# 6         Loot (for Adventurers)    74 393,59        0.95    2600     7800
# 7                        Rarible   100 833,34           0  213500   315500
# 8                        Doodles   130 104,81        12.7    5000    10000
# 9                        Meebits   119 508,55         4.5    6500    20000
# 10                     Moonbirds   142 144,45       26.42    6500    10000
# 11       Otherdeed for Otherside   278 486,21         3.2   34500    98600
# 12  CLONE X - X TAKASHI MURAKAMI   202 596,11        14.5    9300    19300
# 13                  Decentraland   174 219,35        2.27    7200    97500
# 14                         Azuki   241 760,45          13    5100    10000
# 15          Bored Ape Yacht Club    576 677,8          94    6300    10000
# 16         Mutant Ape Yacht Club   401 784,97        18.2   12500    19300
# 17                   CryptoPunks   908 074,25           0    3500    10000
# 18        Degenerate Ape Academy   138 887,04        64.9    4300    10000
# 19               Stoned Ape Crew    127 313,1        84.2    4100     4200
# 20         Famous Fox Federation   112 415,49          55    4000     7800
# 21               MOUS IN DA HOUS   104 316,47         8.4     799     4400
# 22                    The Suites    103 649,3          10    2700     4900
# 23                   Dazed Ducks   102 528,29         8.2    3500    10000
# 24                       SOLgods   108 030,36          50    1100     6700
# 25                 Space Runners   123 165,75          10    5100     9800
# 26               Blocksmith Labs   138 156,72         122    2800     4400
# 27       TombStoned High Society   136 385,83          15     855     6600
# 28                       ASTRALS   138 187,67          10    3700    10000
# 29           Shadowy Super Coder   228 400,45           0     151    10000
# 30      Communi3: Mad Scientists   187 621,39        35.5    2900     5000
# 31      The Catalina Whale Mixer   167 323,29           0    2000     5600
# 32                       Portals   199 462,77        54.5    2900     5000
# 33                        DeGods   513 557,49         340    4300    10000
# 34                 Cets on Creck   264 484,37          67    4000     7000
# 35                    Okay Bears  1 552 565,6         202    5300    10000
# 36                 DeRace Horses     3 541,13        0.09    1900     5500
# 37     Crypto Raiders Characters      2 282,3        0.01    4500    68900
# 38     The Red Village Champions     2 069,46        0.06    2000    11000
# 39         Brave Frontier Heroes     2 011,86       0.001    2400    20100
# 40   Crypto Unicorns Shadowcorns     1 834,28       0.002   15500       41
# 41       The Martians: Metaverse     1 788,42         0.6     762     5000
# 42                      Ethermon     2 012,55       0.004   65500   299700
# 43            Genesis Curry Flow     2 172,59           0    2200        5
# 44        Chumbi Valley Official     3 100,75        0.18    1800     4100
# 45              Ember Sword Land     3 028,61         0.1    6100    40000
# 46                 PolkaPets TCG        3 483       0.006    4600       42
# 47        Crypto Unicorns Market     10 238,5         0.2    2900    18800
# 48                          BCCG     4 021,48        0.01    5400       58
# 49                 Chicken Derby     4 007,85        0.02    6000    33300
# 50   Crypto Unicorns Land Market     5 013,38        0.07    5600    30000
# 51                MyCryptoHeroes    27 229,22       0.002    5800    78600
# 52     Decentral Games ICE Poker    12 022,75        0.31    4100    33200
# 53                ZED RUN Legacy    46 708,63        0.01   36200   217900
#
#    blockchain currency
# 0    ethereum      eth
# 1    ethereum      eth
# 2    ethereum      eth
# 3    ethereum      eth
# 4    ethereum      eth
# 5    ethereum      eth
# 6    ethereum      eth
# 7    ethereum      eth
# 8    ethereum      eth
# 9    ethereum      eth
# 10   ethereum      eth
# 11   ethereum      eth
# 12   ethereum      eth
# 13   ethereum      eth
# 14   ethereum      eth
# 15   ethereum      eth
# 16   ethereum      eth
# 17   ethereum      eth
# 18     solana      sol
# 19     solana      sol
# 20     solana      sol
# 21     solana      sol
# 22     solana      sol
# 23     solana      sol
# 24     solana      sol
# 25     solana      sol
# 26     solana      sol
# 27     solana      sol
# 28     solana      sol
# 29     solana      sol
# 30     solana      sol
# 31     solana      sol
# 32     solana      sol
# 33     solana      sol
# 34     solana      sol
# 35     solana      sol
# 36    polygon      eth
# 37    polygon      eth
# 38    polygon      eth
# 39    polygon      eth
# 40    polygon      eth
# 41    polygon      eth
# 42    polygon      eth
# 43    polygon      eth
# 44    polygon      eth
# 45    polygon      eth
# 46    polygon      eth
# 47    polygon      eth
# 48    polygon      eth
# 49    polygon      eth
# 50    polygon      eth
# 51    polygon      eth
# 52    polygon      eth
# 53    polygon      eth

# %%
df_collections = pd.read_excel(r'C:\Users\Pc\Documents\Study\MST\S2\NoSQL\mod_nfts.xlsx',sheet_name='collection')
df_collections
# Out:
#                             name       volume  floor price  Owners    items blockchain currency
# 0                    The Sandbox    152 791,7       1.7000   21700   140000   ethereum      eth
# 1                  Cool Cats NFT   106 582,83       3.8400    5500     9900   ethereum      eth
# 2          Bored Ape Kennel Club    98 360,89       7.4000    5500     9600   ethereum      eth
# 3                  CryptoKitties    70 686,82       0.0050  115800  2000000   ethereum      eth
# 4          CrypToadz by GREMPLIN    69 469,78       2.0900    4200     7000   ethereum      eth
# 5                 World of Women     68 943,1       4.6800    5400    10000   ethereum      eth
# 6         Loot (for Adventurers)    74 393,59       0.9500    2600     7800   ethereum      eth
# 7                        Rarible   100 833,34       0.0000  213500   315500   ethereum      eth
# 8                        Doodles   130 104,81      12.7000    5000    10000   ethereum      eth
# 9                        Meebits   119 508,55       4.5000    6500    20000   ethereum      eth
# 10                     Moonbirds   142 144,45      26.4200    6500    10000   ethereum      eth
# 11       Otherdeed for Otherside   278 486,21       3.2000   34500    98600   ethereum      eth
# 12  CLONE X - X TAKASHI MURAKAMI   202 596,11      14.5000    9300    19300   ethereum      eth
# 13                  Decentraland   174 219,35       2.2700    7200    97500   ethereum      eth
# 14                         Azuki   241 760,45      13.0000    5100    10000   ethereum      eth
# 15          Bored Ape Yacht Club    576 677,8      94.0000    6300    10000   ethereum      eth
# 16         Mutant Ape Yacht Club   401 784,97      18.2000   12500    19300   ethereum      eth
# 17                   CryptoPunks   908 074,25       0.0000    3500    10000   ethereum      eth
# 18        Degenerate Ape Academy   138 887,04      64.9000    4300    10000     solana      sol
# 19               Stoned Ape Crew    127 313,1      84.2000    4100     4200     solana      sol
# 20         Famous Fox Federation   112 415,49      55.0000    4000     7800     solana      sol
# 21               MOUS IN DA HOUS   104 316,47       8.4000     799     4400     solana      sol
# 22                    The Suites    103 649,3      10.0000    2700     4900     solana      sol
# 23                   Dazed Ducks   102 528,29       8.2000    3500    10000     solana      sol
# 24                       SOLgods   108 030,36      50.0000    1100     6700     solana      sol
# 25                 Space Runners   123 165,75      10.0000    5100     9800     solana      sol
# 26               Blocksmith Labs   138 156,72     122.0000    2800     4400     solana      sol
# 27       TombStoned High Society   136 385,83      15.0000     855     6600     solana      sol
# 28                       ASTRALS   138 187,67      10.0000    3700    10000     solana      sol
# 29           Shadowy Super Coder   228 400,45       0.0000     151    10000     solana      sol
# 30      Communi3: Mad Scientists   187 621,39      35.5000    2900     5000     solana      sol
# 31      The Catalina Whale Mixer   167 323,29       0.0000    2000     5600     solana      sol
# 32                       Portals   199 462,77      54.5000    2900     5000     solana      sol
# 33                        DeGods   513 557,49     340.0000    4300    10000     solana      sol
# 34                 Cets on Creck   264 484,37      67.0000    4000     7000     solana      sol
# 35                    Okay Bears  1 552 565,6     202.0000    5300    10000     solana      sol
# 36                 DeRace Horses     3 541,13       0.0900    1900     5500    polygon      eth
# 37     Crypto Raiders Characters      2 282,3       0.0100    4500    68900    polygon      eth
# 38     The Red Village Champions     2 069,46       0.0600    2000    11000    polygon      eth
# 39         Brave Frontier Heroes     2 011,86       0.0010    2400    20100    polygon      eth
# 40   Crypto Unicorns Shadowcorns     1 834,28       0.0020   15500       41    polygon      eth
# 41       The Martians: Metaverse     1 788,42       0.6000     762     5000    polygon      eth
# 42                      Ethermon     2 012,55       0.0040   65500   299700    polygon      eth
# 43            Genesis Curry Flow     2 172,59       0.0000    2200        5    polygon      eth
# 44        Chumbi Valley Official     3 100,75       0.1800    1800     4100    polygon      eth
# 45              Ember Sword Land     3 028,61       0.1000    6100    40000    polygon      eth
# 46                 PolkaPets TCG        3 483       0.0060    4600       42    polygon      eth
# 47        Crypto Unicorns Market     10 238,5       0.2000    2900    18800    polygon      eth
# 48                          BCCG     4 021,48       0.0100    5400       58    polygon      eth
# 49                 Chicken Derby     4 007,85       0.0200    6000    33300    polygon      eth
# 50   Crypto Unicorns Land Market     5 013,38       0.0700    5600    30000    polygon      eth
# 51                MyCryptoHeroes    27 229,22       0.0020    5800    78600    polygon      eth
# 52     Decentral Games ICE Poker    12 022,75       0.3100    4100    33200    polygon      eth
# 53                ZED RUN Legacy    46 708,63       0.0100   36200   217900    polygon      eth

# %%
df_collections.rename(columns = {'floor price':'floor_price'}, inplace = True)

# %%
df_collections['id'] = range(1, len(df_collections) + 1)

# %%
for d in dic.keys():
    for col in df_collections['name']:
        if col== dic[d]:
            df_collections['id'].loc[df_collections['name']==col]= d
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_18820\736965057.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_collections['id'].loc[df_collections['name']==col]= d

# %%
df_collections
# Out:
#                             name       volume  floor_price  Owners    items blockchain currency  id
# 0                    The Sandbox    152 791,7       1.7000   21700   140000   ethereum      eth   1
# 1                  Cool Cats NFT   106 582,83       3.8400    5500     9900   ethereum      eth   2
# 2          Bored Ape Kennel Club    98 360,89       7.4000    5500     9600   ethereum      eth   3
# 3                  CryptoKitties    70 686,82       0.0050  115800  2000000   ethereum      eth   4
# 4          CrypToadz by GREMPLIN    69 469,78       2.0900    4200     7000   ethereum      eth   5
# 5                 World of Women     68 943,1       4.6800    5400    10000   ethereum      eth   6
# 6         Loot (for Adventurers)    74 393,59       0.9500    2600     7800   ethereum      eth   7
# 7                        Rarible   100 833,34       0.0000  213500   315500   ethereum      eth   8
# 8                        Doodles   130 104,81      12.7000    5000    10000   ethereum      eth   9
# 9                        Meebits   119 508,55       4.5000    6500    20000   ethereum      eth  10
# 10                     Moonbirds   142 144,45      26.4200    6500    10000   ethereum      eth  11
# 11       Otherdeed for Otherside   278 486,21       3.2000   34500    98600   ethereum      eth  12
# 12  CLONE X - X TAKASHI MURAKAMI   202 596,11      14.5000    9300    19300   ethereum      eth  13
# 13                  Decentraland   174 219,35       2.2700    7200    97500   ethereum      eth  14
# 14                         Azuki   241 760,45      13.0000    5100    10000   ethereum      eth  15
# 15          Bored Ape Yacht Club    576 677,8      94.0000    6300    10000   ethereum      eth  16
# 16         Mutant Ape Yacht Club   401 784,97      18.2000   12500    19300   ethereum      eth  17
# 17                   CryptoPunks   908 074,25       0.0000    3500    10000   ethereum      eth  18
# 18        Degenerate Ape Academy   138 887,04      64.9000    4300    10000     solana      sol  19
# 19               Stoned Ape Crew    127 313,1      84.2000    4100     4200     solana      sol  20
# 20         Famous Fox Federation   112 415,49      55.0000    4000     7800     solana      sol  21
# 21               MOUS IN DA HOUS   104 316,47       8.4000     799     4400     solana      sol  22
# 22                    The Suites    103 649,3      10.0000    2700     4900     solana      sol  23
# 23                   Dazed Ducks   102 528,29       8.2000    3500    10000     solana      sol  24
# 24                       SOLgods   108 030,36      50.0000    1100     6700     solana      sol  25
# 25                 Space Runners   123 165,75      10.0000    5100     9800     solana      sol  26
# 26               Blocksmith Labs   138 156,72     122.0000    2800     4400     solana      sol  27
# 27       TombStoned High Society   136 385,83      15.0000     855     6600     solana      sol  28
# 28                       ASTRALS   138 187,67      10.0000    3700    10000     solana      sol  29
# 29           Shadowy Super Coder   228 400,45       0.0000     151    10000     solana      sol  30
# 30      Communi3: Mad Scientists   187 621,39      35.5000    2900     5000     solana      sol  31
# 31      The Catalina Whale Mixer   167 323,29       0.0000    2000     5600     solana      sol  32
# 32                       Portals   199 462,77      54.5000    2900     5000     solana      sol  33
# 33                        DeGods   513 557,49     340.0000    4300    10000     solana      sol  34
# 34                 Cets on Creck   264 484,37      67.0000    4000     7000     solana      sol  35
# 35                    Okay Bears  1 552 565,6     202.0000    5300    10000     solana      sol  36
# 36                 DeRace Horses     3 541,13       0.0900    1900     5500    polygon      eth  37
# 37     Crypto Raiders Characters      2 282,3       0.0100    4500    68900    polygon      eth  38
# 38     The Red Village Champions     2 069,46       0.0600    2000    11000    polygon      eth  39
# 39         Brave Frontier Heroes     2 011,86       0.0010    2400    20100    polygon      eth  40
# 40   Crypto Unicorns Shadowcorns     1 834,28       0.0020   15500       41    polygon      eth  41
# 41       The Martians: Metaverse     1 788,42       0.6000     762     5000    polygon      eth  42
# 42                      Ethermon     2 012,55       0.0040   65500   299700    polygon      eth  43
# 43            Genesis Curry Flow     2 172,59       0.0000    2200        5    polygon      eth  44
# 44        Chumbi Valley Official     3 100,75       0.1800    1800     4100    polygon      eth  45
# 45              Ember Sword Land     3 028,61       0.1000    6100    40000    polygon      eth  46
# 46                 PolkaPets TCG        3 483       0.0060    4600       42    polygon      eth  47
# 47        Crypto Unicorns Market     10 238,5       0.2000    2900    18800    polygon      eth  48
# 48                          BCCG     4 021,48       0.0100    5400       58    polygon      eth  49
# 49                 Chicken Derby     4 007,85       0.0200    6000    33300    polygon      eth  50
# 50   Crypto Unicorns Land Market     5 013,38       0.0700    5600    30000    polygon      eth  51
# 51                MyCryptoHeroes    27 229,22       0.0020    5800    78600    polygon      eth  52
# 52     Decentral Games ICE Poker    12 022,75       0.3100    4100    33200    polygon      eth  53
# 53                ZED RUN Legacy    46 708,63       0.0100   36200   217900    polygon      eth  54

# %%
df_collections['blockchain']=df_collections['blockchain'].map({'ethereum':1,'solana':2,'polygon':3})

# %%
eth=df_collections.loc[df_collections['blockchain'] == 1, 'currency']
df_collections['currency'].loc[df_collections['blockchain'] == 1]=eth.map({'eth':1})

sol=df_collections.loc[df_collections['blockchain'] == 2, 'currency']
df_collections['currency'].loc[df_collections['blockchain'] == 2]=sol.map({'sol':2})

pol=df_collections.loc[df_collections['blockchain'] == 3, 'currency']
df_collections['currency'].loc[df_collections['blockchain'] == 3]=pol.map({'eth':3})
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_18820\2590300716.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_collections['currency'].loc[df_collections['blockchain'] == 1]=eth.map({'eth':1})
# C:\Users\Pc\AppData\Local\Temp\ipykernel_18820\2590300716.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_collections['currency'].loc[df_collections['blockchain'] == 2]=sol.map({'sol':2})
# C:\Users\Pc\AppData\Local\Temp\ipykernel_18820\2590300716.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_collections['currency'].loc[df_collections['blockchain'] == 3]=pol.map({'eth':3})

# %%
df_collections
# Out:
#                             name       volume  floor_price  Owners    items blockchain currency
# 0                    The Sandbox    152 791,7       1.7000   21700   140000   ethereum      eth
# 1                  Cool Cats NFT   106 582,83       3.8400    5500     9900   ethereum      eth
# 2          Bored Ape Kennel Club    98 360,89       7.4000    5500     9600   ethereum      eth
# 3                  CryptoKitties    70 686,82       0.0050  115800  2000000   ethereum      eth
# 4          CrypToadz by GREMPLIN    69 469,78       2.0900    4200     7000   ethereum      eth
# 5                 World of Women     68 943,1       4.6800    5400    10000   ethereum      eth
# 6         Loot (for Adventurers)    74 393,59       0.9500    2600     7800   ethereum      eth
# 7                        Rarible   100 833,34       0.0000  213500   315500   ethereum      eth
# 8                        Doodles   130 104,81      12.7000    5000    10000   ethereum      eth
# 9                        Meebits   119 508,55       4.5000    6500    20000   ethereum      eth
# 10                     Moonbirds   142 144,45      26.4200    6500    10000   ethereum      eth
# 11       Otherdeed for Otherside   278 486,21       3.2000   34500    98600   ethereum      eth
# 12  CLONE X - X TAKASHI MURAKAMI   202 596,11      14.5000    9300    19300   ethereum      eth
# 13                  Decentraland   174 219,35       2.2700    7200    97500   ethereum      eth
# 14                         Azuki   241 760,45      13.0000    5100    10000   ethereum      eth
# 15          Bored Ape Yacht Club    576 677,8      94.0000    6300    10000   ethereum      eth
# 16         Mutant Ape Yacht Club   401 784,97      18.2000   12500    19300   ethereum      eth
# 17                   CryptoPunks   908 074,25       0.0000    3500    10000   ethereum      eth
# 18        Degenerate Ape Academy   138 887,04      64.9000    4300    10000     solana      sol
# 19               Stoned Ape Crew    127 313,1      84.2000    4100     4200     solana      sol
# 20         Famous Fox Federation   112 415,49      55.0000    4000     7800     solana      sol
# 21               MOUS IN DA HOUS   104 316,47       8.4000     799     4400     solana      sol
# 22                    The Suites    103 649,3      10.0000    2700     4900     solana      sol
# 23                   Dazed Ducks   102 528,29       8.2000    3500    10000     solana      sol
# 24                       SOLgods   108 030,36      50.0000    1100     6700     solana      sol
# 25                 Space Runners   123 165,75      10.0000    5100     9800     solana      sol
# 26               Blocksmith Labs   138 156,72     122.0000    2800     4400     solana      sol
# 27       TombStoned High Society   136 385,83      15.0000     855     6600     solana      sol
# 28                       ASTRALS   138 187,67      10.0000    3700    10000     solana      sol
# 29           Shadowy Super Coder   228 400,45       0.0000     151    10000     solana      sol
# 30      Communi3: Mad Scientists   187 621,39      35.5000    2900     5000     solana      sol
# 31      The Catalina Whale Mixer   167 323,29       0.0000    2000     5600     solana      sol
# 32                       Portals   199 462,77      54.5000    2900     5000     solana      sol
# 33                        DeGods   513 557,49     340.0000    4300    10000     solana      sol
# 34                 Cets on Creck   264 484,37      67.0000    4000     7000     solana      sol
# 35                    Okay Bears  1 552 565,6     202.0000    5300    10000     solana      sol
# 36                 DeRace Horses     3 541,13       0.0900    1900     5500    polygon      eth
# 37     Crypto Raiders Characters      2 282,3       0.0100    4500    68900    polygon      eth
# 38     The Red Village Champions     2 069,46       0.0600    2000    11000    polygon      eth
# 39         Brave Frontier Heroes     2 011,86       0.0010    2400    20100    polygon      eth
# 40   Crypto Unicorns Shadowcorns     1 834,28       0.0020   15500       41    polygon      eth
# 41       The Martians: Metaverse     1 788,42       0.6000     762     5000    polygon      eth
# 42                      Ethermon     2 012,55       0.0040   65500   299700    polygon      eth
# 43            Genesis Curry Flow     2 172,59       0.0000    2200        5    polygon      eth
# 44        Chumbi Valley Official     3 100,75       0.1800    1800     4100    polygon      eth
# 45              Ember Sword Land     3 028,61       0.1000    6100    40000    polygon      eth
# 46                 PolkaPets TCG        3 483       0.0060    4600       42    polygon      eth
# 47        Crypto Unicorns Market     10 238,5       0.2000    2900    18800    polygon      eth
# 48                          BCCG     4 021,48       0.0100    5400       58    polygon      eth
# 49                 Chicken Derby     4 007,85       0.0200    6000    33300    polygon      eth
# 50   Crypto Unicorns Land Market     5 013,38       0.0700    5600    30000    polygon      eth
# 51                MyCryptoHeroes    27 229,22       0.0020    5800    78600    polygon      eth
# 52     Decentral Games ICE Poker    12 022,75       0.3100    4100    33200    polygon      eth
# 53                ZED RUN Legacy    46 708,63       0.0100   36200   217900    polygon      eth

# %%
df_collections.dtypes #????volume and currency are strings
# Out:
# name            object
# volume          object
# floor_price    float64
# Owners           int64
# items            int64
# blockchain      object
# currency        object
# dtype: object

# %%
df_collections["currency"] = pd.to_numeric(df_collections["currency"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\users\pc\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "eth"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 df_collections["currency"] = pd.to_numeric(df_collections["currency"])
#
# File c:\users\pc\appdata\local\programs\python\python39\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# File c:\users\pc\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\lib.pyx:2357, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "eth" at position 0

# %%
df_collections["volume"]=df_collections["volume"].str.replace(",", ".")
df_collections["volume"]=df_collections["volume"].str.replace("\u202f", "")
df_collections["volume"] = pd.to_numeric(df_collections["volume"])

# %%
df_collections.dtypes
# Out:
# name            object
# volume         float64
# floor_price    float64
# Owners           int64
# items            int64
# blockchain      object
# currency        object
# id               int64
# dtype: object

# %%
df_collections.describe()
# Out:
#             volume  floor_price      Owners        items      id
# count      54.0000      54.0000     54.0000      54.0000 54.0000
# mean   157415.5026      24.9598  12932.7222   70410.1111 27.5000
# std    252551.6151      57.3630  33228.3939  275668.9053 15.7321
# min      1788.4200       0.0000    151.0000       5.0000  1.0000
# 25%      6319.6600       0.0125   2825.0000    5850.0000 14.2500
# 50%    105449.6500       2.7350   4400.0000   10000.0000 27.5000
# 75%    163690.3925      14.8750   6075.0000   20075.0000 40.7500
# max   1552565.6000     340.0000 213500.0000 2000000.0000 54.0000

# %%
num_outliers=len(detect_outliers_iqr(df_collections['floor_price']))
print(num_outliers)
print(df_collections.shape[0])
# Out:
# 10
# 54

# %%
pourcentage_oultiers = num_outliers/df_collections.shape[0]
print(pourcentage_oultiers*100)
# Out:
# 18.51851851851852

# %%
blockchains = df_collections['blockchain'].unique()
new_floor_price = []
for block in blockchains:
    grp=df_collections.loc[df_collections['blockchain'] == block]
    # nfts_outliers = detect_outliers_iqr(grp['last price'])
    # print("Outliers from IQR method: ", nfts_outliers)
    plt.figure(figsize =(10, 10))
    plot=grp.boxplot(['floor_price'])
    collections_outliers1 = detect_outliers_iqr(grp['floor_price'])
    print("Outliers from IQR method: ", collections_outliers1)
    grp['floor_price'] =replace_outliers(grp['floor_price'])
    # df_nfts['last price']=grp['last price']
    new_floor_price.append(grp['floor_price'].tolist())
# Out:
# Outliers from IQR method:  [94.0]
# The before : Outliers from IQR method:  [94.0]
# median  4.17
# Outliers from IQR method:  [202.0, 340.0]
# The before : Outliers from IQR method:  [202.0, 340.0]
# median  42.75
# Outliers from IQR method:  [0.31, 0.6]
# The before : Outliers from IQR method:  [0.31, 0.6]
# median  0.015
# C:\Users\Pc\AppData\Local\Temp\ipykernel_824\3419594452.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grp['floor_price'] =replace_outliers(grp['floor_price'])
# C:\Users\Pc\AppData\Local\Temp\ipykernel_824\3419594452.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grp['floor_price'] =replace_outliers(grp['floor_price'])
# C:\Users\Pc\AppData\Local\Temp\ipykernel_824\3419594452.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grp['floor_price'] =replace_outliers(grp['floor_price'])

# %%
new_floor_price = flatten(new_floor_price)
print(new_floor_price)
df_collections['floor_price'] =new_floor_price
# Out:
# [1.7, 3.84, 7.4, 0.005, 2.09, 4.68, 0.95, 0.0, 12.7, 4.5, 26.42, 3.2, 14.5, 2.27, 13.0, 4.17, 18.2, 0.0, 64.9, 84.2, 55.0, 8.4, 10.0, 8.2, 50.0, 10.0, 122.0, 15.0, 10.0, 0.0, 35.5, 0.0, 54.5, 42.75, 67.0, 42.75, 0.09, 0.01, 0.06, 0.001, 0.002, 0.015, 0.004, 0.0, 0.18, 0.1, 0.006, 0.2, 0.01, 0.02, 0.07, 0.002, 0.015, 0.01]

# %%
grp1=df_collections.loc[df_collections['blockchain'] == 'ethereum']
plt.figure(figsize =(10, 10))
plot=grp1.boxplot(['floor_price'])
collections_outliers1 = detect_outliers_iqr(grp1['floor_price'])
print("Outliers from IQR method: ", collections_outliers1)
# Out:
# Outliers from IQR method:  [26.42]

# %%
df_collections.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# dtype: bool

# %% [markdown]
# # Blockchains

# %%
df_blockchains = pd.read_excel (r'C:\Users\Pc\Documents\Study\MST\S2\NoSQL\mod_nfts.xlsx',sheet_name='blockchain')
df_blockchains
# Out:
#        name  id
# 0  ethereum   1
# 1    solana   2
# 2   polygon   3

# %% [markdown]
# puisque le min trouve < min de describe => donc le vrai min de notre data est : -573.5

# %% [markdown]
# puisque le max trouve < max de describe =>donc le vrai max est 982.5

# %%
d_currency = {'name': ['eth','SAND','USDC','weth','MANA','sol','eth','weth'], 'id': [11, 12,13,14,15,2,31,32],'id_blockchain':[1,1,1,1,1,2,3,3]}
df_currency = pd.DataFrame(data=d_currency)
df_currency
# Out:
#    name  id  id_blockchain
# 0   eth  11              1
# 1  SAND  12              1
# 2  USDC  13              1
# 3  weth  14              1
# 4  MANA  15              1
# 5   sol   2              2
# 6   eth  31              3
# 7  weth  32              3

# %%
writer = pd.ExcelWriter('cleaned_nfts.xlsx', engine='xlsxwriter')
df_blockchains.to_excel(writer,sheet_name='blockchain', index = False)
df_collections.to_excel(writer,sheet_name='collection', index = False)
df_nfts.to_excel(writer,sheet_name='nft', index = False)
# df_currency.to_excel(writer,sheet_name='currency', index = False)

writer.save()

# %% [markdown]
# # Store in MongoDB

# %%
# importing Mongoclient from pymongo
from pymongo import MongoClient

 
myclient = MongoClient("mongodb+srv://soumaya:soumaya1Atlas@cluster0.y9xab.mongodb.net/test?retryWrites=true&w=majority")
 
# database
db = myclient["DjangoDB"]
 

blockchains_col = db["DjangoApp_blockchain"]
collections_col = db["DjangoApp_collection"]
nfts_col = db["DjangoApp_nft"]
# currency_col = db["currency"]

# %%
import json
blockchain = json.loads(df_blockchains.to_json(orient='records'))
collection = json.loads(df_collections.to_json(orient='records'))
nft = json.loads(df_nfts.to_json(orient='records'))
# currency = json.loads(df_currency.to_json(orient='records'))

# %%
blockchain
# Out:
# [{'name': 'ethereum', 'id': 1},
#  {'name': 'solana', 'id': 2},
#  {'name': 'polygon', 'id': 3}]

# %%
collection
# Out:
# [{'name': 'The Sandbox',
#   'volume': 152791.7,
#   'floor_price': 1.7,
#   'Owners': 21700,
#   'items': 140000,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 1},
#  {'name': 'Cool Cats NFT',
#   'volume': 106582.83,
#   'floor_price': 3.84,
#   'Owners': 5500,
#   'items': 9900,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 2},
#  {'name': 'Bored Ape Kennel Club',
#   'volume': 98360.89,
#   'floor_price': 7.4,
#   'Owners': 5500,
#   'items': 9600,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 3},
#  {'name': 'CryptoKitties',
#   'volume': 70686.82,
#   'floor_price': 0.005,
#   'Owners': 115800,
#   'items': 2000000,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 4},
#  {'name': 'CrypToadz by GREMPLIN',
#   'volume': 69469.78,
#   'floor_price': 2.09,
#   'Owners': 4200,
#   'items': 7000,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 5},
#  {'name': 'World of Women',
#   'volume': 68943.1,
#   'floor_price': 4.68,
#   'Owners': 5400,
#   'items': 10000,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 6},
#  {'name': 'Loot (for Adventurers)',
#   'volume': 74393.59,
#   'floor_price': 0.95,
#   'Owners': 2600,
#   'items': 7800,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 7},
#  {'name': 'Rarible',
#   'volume': 100833.34,
#   'floor_price': 0.0,
#   'Owners': 213500,
#   'items': 315500,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 8},
#  {'name': 'Doodles',
#   'volume': 130104.81,
#   'floor_price': 12.7,
#   'Owners': 5000,
#   'items': 10000,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 9},
#  {'name': 'Meebits',
#   'volume': 119508.55,
#   'floor_price': 4.5,
#   'Owners': 6500,
#   'items': 20000,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 10},
#  {'name': 'Moonbirds',
#   'volume': 142144.45,
#   'floor_price': 26.42,
#   'Owners': 6500,
#   'items': 10000,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 11},
#  {'name': 'Otherdeed for Otherside',
#   'volume': 278486.21,
#   'floor_price': 3.2,
#   'Owners': 34500,
#   'items': 98600,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 12},
#  {'name': 'CLONE X - X TAKASHI MURAKAMI',
#   'volume': 202596.11,
#   'floor_price': 14.5,
#   'Owners': 9300,
#   'items': 19300,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 13},
#  {'name': 'Decentraland',
#   'volume': 174219.35,
#   'floor_price': 2.27,
#   'Owners': 7200,
#   'items': 97500,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 14},
#  {'name': 'Azuki',
#   'volume': 241760.45,
#   'floor_price': 13.0,
#   'Owners': 5100,
#   'items': 10000,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 15},
#  {'name': 'Bored Ape Yacht Club',
#   'volume': 576677.8,
#   'floor_price': 4.17,
#   'Owners': 6300,
#   'items': 10000,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 16},
#  {'name': 'Mutant Ape Yacht Club',
#   'volume': 401784.97,
#   'floor_price': 18.2,
#   'Owners': 12500,
#   'items': 19300,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 17},
#  {'name': 'CryptoPunks',
#   'volume': 908074.25,
#   'floor_price': 0.0,
#   'Owners': 3500,
#   'items': 10000,
#   'blockchain': 'ethereum',
#   'currency': 'eth',
#   'id': 18},
#  {'name': 'Degenerate Ape Academy',
#   'volume': 138887.04,
#   'floor_price': 64.9,
#   'Owners': 4300,
#   'items': 10000,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 19},
#  {'name': 'Stoned Ape Crew',
#   'volume': 127313.1,
#   'floor_price': 84.2,
#   'Owners': 4100,
#   'items': 4200,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 20},
#  {'name': 'Famous Fox Federation',
#   'volume': 112415.49,
#   'floor_price': 55.0,
#   'Owners': 4000,
#   'items': 7800,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 21},
#  {'name': 'MOUS IN DA HOUS',
#   'volume': 104316.47,
#   'floor_price': 8.4,
#   'Owners': 799,
#   'items': 4400,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 22},
#  {'name': 'The Suites',
#   'volume': 103649.3,
#   'floor_price': 10.0,
#   'Owners': 2700,
#   'items': 4900,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 23},
#  {'name': 'Dazed Ducks',
#   'volume': 102528.29,
#   'floor_price': 8.2,
#   'Owners': 3500,
#   'items': 10000,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 24},
#  {'name': 'SOLgods',
#   'volume': 108030.36,
#   'floor_price': 50.0,
#   'Owners': 1100,
#   'items': 6700,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 25},
#  {'name': 'Space Runners',
#   'volume': 123165.75,
#   'floor_price': 10.0,
#   'Owners': 5100,
#   'items': 9800,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 26},
#  {'name': 'Blocksmith Labs',
#   'volume': 138156.72,
#   'floor_price': 122.0,
#   'Owners': 2800,
#   'items': 4400,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 27},
#  {'name': 'TombStoned High Society',
#   'volume': 136385.83,
#   'floor_price': 15.0,
#   'Owners': 855,
#   'items': 6600,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 28},
#  {'name': 'ASTRALS',
#   'volume': 138187.67,
#   'floor_price': 10.0,
#   'Owners': 3700,
#   'items': 10000,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 29},
#  {'name': 'Shadowy Super Coder',
#   'volume': 228400.45,
#   'floor_price': 0.0,
#   'Owners': 151,
#   'items': 10000,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 30},
#  {'name': 'Communi3: Mad Scientists',
#   'volume': 187621.39,
#   'floor_price': 35.5,
#   'Owners': 2900,
#   'items': 5000,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 31},
#  {'name': 'The Catalina Whale Mixer',
#   'volume': 167323.29,
#   'floor_price': 0.0,
#   'Owners': 2000,
#   'items': 5600,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 32},
#  {'name': 'Portals',
#   'volume': 199462.77,
#   'floor_price': 54.5,
#   'Owners': 2900,
#   'items': 5000,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 33},
#  {'name': 'DeGods',
#   'volume': 513557.49,
#   'floor_price': 42.75,
#   'Owners': 4300,
#   'items': 10000,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 34},
#  {'name': 'Cets on Creck',
#   'volume': 264484.37,
#   'floor_price': 67.0,
#   'Owners': 4000,
#   'items': 7000,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 35},
#  {'name': 'Okay Bears',
#   'volume': 1552565.6,
#   'floor_price': 42.75,
#   'Owners': 5300,
#   'items': 10000,
#   'blockchain': 'solana',
#   'currency': 'sol',
#   'id': 36},
#  {'name': 'DeRace Horses',
#   'volume': 3541.13,
#   'floor_price': 0.09,
#   'Owners': 1900,
#   'items': 5500,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 37},
#  {'name': 'Crypto Raiders Characters',
#   'volume': 2282.3,
#   'floor_price': 0.01,
#   'Owners': 4500,
#   'items': 68900,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 38},
#  {'name': 'The Red Village Champions',
#   'volume': 2069.46,
#   'floor_price': 0.06,
#   'Owners': 2000,
#   'items': 11000,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 39},
#  {'name': 'Brave Frontier Heroes',
#   'volume': 2011.86,
#   'floor_price': 0.001,
#   'Owners': 2400,
#   'items': 20100,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 40},
#  {'name': 'Crypto Unicorns Shadowcorns',
#   'volume': 1834.28,
#   'floor_price': 0.002,
#   'Owners': 15500,
#   'items': 41,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 41},
#  {'name': 'The Martians: Metaverse',
#   'volume': 1788.42,
#   'floor_price': 0.015,
#   'Owners': 762,
#   'items': 5000,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 42},
#  {'name': 'Ethermon',
#   'volume': 2012.55,
#   'floor_price': 0.004,
#   'Owners': 65500,
#   'items': 299700,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 43},
#  {'name': 'Genesis Curry Flow',
#   'volume': 2172.59,
#   'floor_price': 0.0,
#   'Owners': 2200,
#   'items': 5,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 44},
#  {'name': 'Chumbi Valley Official',
#   'volume': 3100.75,
#   'floor_price': 0.18,
#   'Owners': 1800,
#   'items': 4100,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 45},
#  {'name': 'Ember Sword Land',
#   'volume': 3028.61,
#   'floor_price': 0.1,
#   'Owners': 6100,
#   'items': 40000,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 46},
#  {'name': 'PolkaPets TCG',
#   'volume': 3483.0,
#   'floor_price': 0.006,
#   'Owners': 4600,
#   'items': 42,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 47},
#  {'name': 'Crypto Unicorns Market',
#   'volume': 10238.5,
#   'floor_price': 0.2,
#   'Owners': 2900,
#   'items': 18800,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 48},
#  {'name': 'BCCG',
#   'volume': 4021.48,
#   'floor_price': 0.01,
#   'Owners': 5400,
#   'items': 58,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 49},
#  {'name': 'Chicken Derby',
#   'volume': 4007.85,
#   'floor_price': 0.02,
#   'Owners': 6000,
#   'items': 33300,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 50},
#  {'name': 'Crypto Unicorns Land Market',
#   'volume': 5013.38,
#   'floor_price': 0.07,
#   'Owners': 5600,
#   'items': 30000,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 51},
#  {'name': 'MyCryptoHeroes',
#   'volume': 27229.22,
#   'floor_price': 0.002,
#   'Owners': 5800,
#   'items': 78600,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 52},
#  {'name': 'Decentral Games ICE Poker',
#   'volume': 12022.75,
#   'floor_price': 0.015,
#   'Owners': 4100,
#   'items': 33200,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 53},
#  {'name': 'ZED RUN Legacy',
#   'volume': 46708.63,
#   'floor_price': 0.01,
#   'Owners': 36200,
#   'items': 217900,
#   'blockchain': 'polygon',
#   'currency': 'eth',
#   'id': 54}]

# %%
blockchains_col.insert_many(blockchain)
collections_col.insert_many(collection)
nfts_col.insert_many(nft)
# currency_col.insert_many(currency)
